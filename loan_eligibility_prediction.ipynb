# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/train_u6lujuX_CVtuZ9i.csv'
loan = pd.read_csv(file_path)

# %%
loan.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
len(loan)
# Out:
# 614

# %%
loan.shape
# Out:
# (614, 13)

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df=loan.dropna()

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
df['gender']=label.fit_transform(df['Gender'])
# Out:
# <ipython-input-34-0ffc9d21d121>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gender']=label.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status  gender
# 1             1.0         Rural           N       1
# 2             1.0         Urban           Y       1
# 3             1.0         Urban           Y       1
# 4             1.0         Urban           Y       1
# 5             1.0         Urban           Y       1

# %%
df['married']=label.fit_transform(df['Married'])
df['education']=label.fit_transform(df['Education'])
df['area']=label.fit_transform(df['Property_Area'])
df['loan_status']=label.fit_transform(df['Loan_Status'])
df['loan_id']=label.fit_transform(df['Loan_ID'])
df['self_employement']=label.fit_transform(df['Self_Employed'])
# Out:
# <ipython-input-40-6fdb5fe809a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['married']=label.fit_transform(df['Married'])
# <ipython-input-40-6fdb5fe809a3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['education']=label.fit_transform(df['Education'])
# <ipython-input-40-6fdb5fe809a3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area']=label.fit_transform(df['Property_Area'])
# <ipython-input-40-6fdb5fe809a3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_status']=label.fit_transform(df['Loan_Status'])
# <ipython-input-40-6fdb5fe809a3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['loan_id']=label.fit_transform(df['Loan_ID'])
# <ipython-input-40-6fdb5fe809a3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['self_employement']=label.fit_transform(df['Self_Employed'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status  gender  married  education  area  \
# 1             1.0         Rural           N       1        1          0     0
# 2             1.0         Urban           Y       1        1          0     2
# 3             1.0         Urban           Y       1        1          1     2
# 4             1.0         Urban           Y       1        0          0     2
# 5             1.0         Urban           Y       1        1          0     2
#
#    loan_status  loan_id  self_employement
# 1            0        0                 0
# 2            1        1                 1
# 3            1        2                 0
# 4            1        3                 0
# 5            1        4                 1

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status  gender  married  education  \
# 609             1.0         Rural           Y       0        0          0
# 610             1.0         Rural           Y       1        1          0
# 611             1.0         Urban           Y       1        1          0
# 612             1.0         Urban           Y       1        1          0
# 613             0.0     Semiurban           N       0        0          0
#
#      area  loan_status  loan_id  self_employement
# 609     0            1      475                 0
# 610     0            1      476                 0
# 611     2            1      477                 0
# 612     2            1      478                 0
# 613     1            0      479                 1

# %%
data=['Gender','Married','Education','Loan_Status','Property_Area','Loan_ID']
df.drop(columns=data,axis=1)
# Out:
#     Dependents Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1            1            No             4583             1508.0       128.0
# 2            0           Yes             3000                0.0        66.0
# 3            0            No             2583             2358.0       120.0
# 4            0            No             6000                0.0       141.0
# 5            2           Yes             5417             4196.0       267.0
# ..         ...           ...              ...                ...         ...
# 609          0            No             2900                0.0        71.0
# 610         3+            No             4106                0.0        40.0
# 611          1            No             8072              240.0       253.0
# 612          2            No             7583                0.0       187.0
# 613          0           Yes             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History  gender  married  education  area  \
# 1               360.0             1.0       1        1          0     0
# 2               360.0             1.0       1        1          0     2
# 3               360.0             1.0       1        1          1     2
# 4               360.0             1.0       1        0          0     2
# 5               360.0             1.0       1        1          0     2
# ..                ...             ...     ...      ...        ...   ...
# 609             360.0             1.0       0        0          0     0
# 610             180.0             1.0       1        1          0     0
# 611             360.0             1.0       1        1          0     2
# 612             360.0             1.0       1        1          0     2
# 613             360.0             0.0       0        0          0     1
#
#      loan_status  loan_id  self_employement
# 1              0        0                 0
# 2              1        1                 1
# 3              1        2                 0
# 4              1        3                 0
# 5              1        4                 1
# ..           ...      ...               ...
# 609            1      475                 0
# 610            1      476                 0
# 611            1      477                 0
# 612            1      478                 0
# 613            0      479                 1
#
# [480 rows x 14 columns]

# %%
data=['Gender','Married','Education','Loan_Status','Property_Area','Loan_ID','Self_Employed']
df.drop(columns=data,axis=1)
# Out:
#     Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1            1             4583             1508.0       128.0
# 2            0             3000                0.0        66.0
# 3            0             2583             2358.0       120.0
# 4            0             6000                0.0       141.0
# 5            2             5417             4196.0       267.0
# ..         ...              ...                ...         ...
# 609          0             2900                0.0        71.0
# 610         3+             4106                0.0        40.0
# 611          1             8072              240.0       253.0
# 612          2             7583                0.0       187.0
# 613          0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History  gender  married  education  area  \
# 1               360.0             1.0       1        1          0     0
# 2               360.0             1.0       1        1          0     2
# 3               360.0             1.0       1        1          1     2
# 4               360.0             1.0       1        0          0     2
# 5               360.0             1.0       1        1          0     2
# ..                ...             ...     ...      ...        ...   ...
# 609             360.0             1.0       0        0          0     0
# 610             180.0             1.0       1        1          0     0
# 611             360.0             1.0       1        1          0     2
# 612             360.0             1.0       1        1          0     2
# 613             360.0             0.0       0        0          0     1
#
#      loan_status  loan_id  self_employement
# 1              0        0                 0
# 2              1        1                 1
# 3              1        2                 0
# 4              1        3                 0
# 5              1        4                 1
# ..           ...      ...               ...
# 609            1      475                 0
# 610            1      476                 0
# 611            1      477                 0
# 612            1      478                 0
# 613            0      479                 1
#
# [480 rows x 13 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.hist(df['ApplicantIncome'], bins=30, edgecolor='black')
plt.show()

# %%
sns.scatterplot(x='ApplicantIncome', y='LoanAmount', data=df)
plt.show()

# %%
sns.countplot(x='gender', hue='loan_status', data=df)
plt.title('Loan Approval by Gender')
plt.show()
